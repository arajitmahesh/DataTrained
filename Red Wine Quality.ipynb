# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# As mentioned in the question if quality is > 7, only then it is classified as good, othwerwise it is not good.

# %%
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# From the above graph we can say that the quality of wine is mostly of not good quality

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
for i in df.columns:
    sns.lineplot(x='quality',y=i,data=df)
    plt.show()

# %% [markdown]
# As we can observe,
#
# Increase in 'Citric acid', 'Sulphates' and 'Alcohol' increases the quality of wine.
#
# High range of 'Volatile acidity' and 'Chlorides' impact the quality of wine.
#
# 'Fixed acidity', 'Chlorides' and 'Free sulfur dioxide' does not create much impact on the quality of wine
#
# 'Residual sugar' and 'ph' has no impact on the overall quality of the wine. We can drop this column for model building.

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# Most of the data is normally distributed.
#
# There is slight skew in 'Residual sugar' and 'Chlorides'

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(), cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can observe, there is not much correlation between any feature

# %%
for i in df.columns:
    plt.subplots()
    sns.boxplot(df[i])

# %% [markdown]
# There are many outliers present in the data. Our dataset is not huge and consist of only 1599 rows hence we have to check how much data we will lose if we remove the ouliers

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
df.drop(['residual sugar','pH'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  chlorides  \
# 0            7.4              0.70         0.00      0.076
# 1            7.8              0.88         0.00      0.098
# 2            7.8              0.76         0.04      0.092
# 3           11.2              0.28         0.56      0.075
# 4            7.4              0.70         0.00      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# 0                 11.0                  34.0   0.9978       0.56      9.4
# 1                 25.0                  67.0   0.9968       0.68      9.8
# 2                 15.0                  54.0   0.9970       0.65      9.8
# 3                 17.0                  60.0   0.9980       0.58      9.8
# 4                 11.0                  34.0   0.9978       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %% [markdown]
# Dropped Residual sugar, ph as the correlation is less

# %% [markdown]
# Replacing wine quality by 0 & 1,0 if quality is less than 7 and 1 if quality is greater/equal to 7

# %%
df['quality'] = np.where((df.quality >= 7), 1, 0)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  chlorides  \
# 0            7.4              0.70         0.00      0.076
# 1            7.8              0.88         0.00      0.098
# 2            7.8              0.76         0.04      0.092
# 3           11.2              0.28         0.56      0.075
# 4            7.4              0.70         0.00      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# 0                 11.0                  34.0   0.9978       0.56      9.4
# 1                 25.0                  67.0   0.9968       0.68      9.8
# 2                 15.0                  54.0   0.9970       0.65      9.8
# 3                 17.0                  60.0   0.9980       0.58      9.8
# 4                 11.0                  34.0   0.9978       0.56      9.4
#
#    quality
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
from scipy.stats import zscore
z=np.abs(zscore(df.drop(columns=['quality'])))
z
# Out:
# array([[0.52835961, 0.96187667, 1.39147228, ..., 0.55827446, 0.57920652,
#         0.96024611],
#        [0.29854743, 1.96744245, 1.39147228, ..., 0.02826077, 0.1289504 ,
#         0.58477711],
#        [0.29854743, 1.29706527, 1.18607043, ..., 0.13426351, 0.04808883,
#         0.58477711],
#        ...,
#        [1.1603431 , 0.09955388, 0.72391627, ..., 0.53355375, 0.54204194,
#         0.54162988],
#        [1.39015528, 0.65462046, 0.77526673, ..., 0.67665745, 0.30598963,
#         0.20930812],
#        [1.33270223, 1.21684919, 1.02199944, ..., 0.66605717, 0.01092425,
#         0.54162988]])

# %%
print('Shape before removing the outliers:', df.shape)
 
dfnew=df[(z<3).all(axis=1)]
 
print('Shape after removing the outliers:', dfnew.shape)
# Out:
# Shape before removing the outliers: (1599, 10)
# Shape after removing the outliers: (1483, 10)

# %%
100-((1483/1599)*100)
# Out:
# 7.254534083802383

# %%
1599-1483
# Out:
# 116

# %% [markdown]
# Percentage of lost data lost = 7.25%(116 rows)

# %%
dfnew.skew()
# Out:
# fixed acidity           0.793077
# volatile acidity        0.385444
# citric acid             0.304663
# chlorides               2.270552
# free sulfur dioxide     0.850137
# total sulfur dioxide    1.156051
# density                 0.043847
# sulphates               0.903161
# alcohol                 0.753694
# quality                 2.114961
# dtype: float64

# %%
from scipy.stats import boxcox
ds=dfnew

# %%
bc, var=boxcox(ds['chlorides'])
dfnew['chlorides'],var=boxcox(ds['chlorides'])
dfnew['chlorides'].skew()
dfnew.skew()
bc, var=boxcox(ds['total sulfur dioxide'])

# %%
sns.distplot(bc)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# We can see now that the data looks normally dustributed

# %%
dfnew['total sulfur dioxide'],var=boxcox(ds['total sulfur dioxide'])

# %%
dfnew.skew()
# Out:
# fixed acidity           0.793077
# volatile acidity        0.385444
# citric acid             0.304663
# chlorides              -0.056486
# free sulfur dioxide     0.850137
# total sulfur dioxide   -0.011942
# density                 0.043847
# sulphates               0.903161
# alcohol                 0.753694
# quality                 2.114961
# dtype: float64

# %%
columns=['fixed acidity','free sulfur dioxide','sulphates','alcohol']
 
for i in columns:
    ds[i]=np.cbrt(ds[i])

# %%
ds.skew()
# Out:
# fixed acidity           0.483249
# volatile acidity        0.385444
# citric acid             0.304663
# chlorides              -0.056486
# free sulfur dioxide     0.115106
# total sulfur dioxide   -0.011942
# density                 0.043847
# sulphates               0.535850
# alcohol                 0.641651
# quality                 2.114961
# dtype: float64

# %%
x=ds.drop(columns='quality')
y=ds['quality']

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  chlorides  \
# 0       1.948695              0.70         0.00  -4.225805
# 1       1.983192              0.88         0.00  -3.616401
# 2       1.983192              0.76         0.04  -3.762722
# 3       2.237378              0.28         0.56  -4.259094
# 4       1.948695              0.70         0.00  -4.225805
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates   alcohol
# 0             2.223980              4.021228   0.9978   0.824257  2.110454
# 1             2.924018              4.920517   0.9968   0.879366  2.139975
# 2             2.466212              4.629707   0.9970   0.866239  2.139975
# 3             2.571282              4.771179   0.9980   0.833955  2.139975
# 4             2.223980              4.021228   0.9978   0.824257  2.110454

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: quality, dtype: int32

# %%
y.value_counts()
# Out:
# 0    1280
# 1     203
# Name: quality, dtype: int64

# %% [markdown]
# Dataset seems imbalanced

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
X,Y=SM.fit_resample(x,y)
y_new=pd.DataFrame(data=Y)

# %%
y_new.value_counts()
# Out:
# quality
# 1          1280
# 0          1280
# dtype: int64

# %%
x_new=pd.DataFrame(data=X)

# %%
x_new.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  chlorides  \
# 0       1.948695              0.70         0.00  -4.225805
# 1       1.983192              0.88         0.00  -3.616401
# 2       1.983192              0.76         0.04  -3.762722
# 3       2.237378              0.28         0.56  -4.259094
# 4       1.948695              0.70         0.00  -4.225805
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates   alcohol
# 0             2.223980              4.021228   0.9978   0.824257  2.110454
# 1             2.924018              4.920517   0.9968   0.879366  2.139975
# 2             2.466212              4.629707   0.9970   0.866239  2.139975
# 3             2.571282              4.771179   0.9980   0.833955  2.139975
# 4             2.223980              4.021228   0.9978   0.824257  2.110454

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc_x=sc.fit_transform(x_new)
sc_x
# Out:
# array([[-0.65631883,  1.38832349, -1.64485354, ...,  0.75930496,
#         -0.97484053, -1.41680538],
#        [-0.39453424,  2.48646861, -1.64485354, ...,  0.19573689,
#          0.01014366, -1.01391352],
#        [-0.39453424,  1.75437186, -1.43723534, ...,  0.30845051,
#         -0.2244777 , -1.01391352],
#        ...,
#        [ 1.12536282, -0.78062432,  0.87189646, ..., -0.23448121,
#          0.37066706,  0.92849299],
#        [ 1.61919718, -0.98072014,  1.20270238, ...,  1.66739359,
#          1.39064481,  0.07275702],
#        [-2.04188295,  1.60718709, -1.29179977, ..., -2.38213137,
#          1.14188396,  1.95900894]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(sc_x,y_new,test_size=.30,random_state=i)
    mod=KNeighborsClassifier(n_neighbors=5)
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy is',maxAccu,' on Random state',maxRS)
# Out:
# Best Accuracy is 0.91796875  on Random state 96

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=96)

# %%
lg=LogisticRegression()
rfc=RandomForestClassifier(n_estimators=100)
dt=DecisionTreeClassifier()
sv=SVC(probability=True)
knn=KNeighborsClassifier(n_neighbors=5)

# %%
model=(lg,rfc,dt,sv,knn)
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('Accuracy score of',m)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
# Out:
# Accuracy score of LogisticRegression()
# 0.8719101123595505
# [[381   8]
#  [ 49   7]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       389
#            1       0.47      0.12      0.20        56
#
#     accuracy                           0.87       445
#    macro avg       0.68      0.55      0.56       445
# weighted avg       0.83      0.87      0.84       445
#
# Accuracy score of RandomForestClassifier()
# 0.9168539325842696
# [[379  10]
#  [ 27  29]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       389
#            1       0.74      0.52      0.61        56
#
#     accuracy                           0.92       445
#    macro avg       0.84      0.75      0.78       445
# weighted avg       0.91      0.92      0.91       445
#
# Accuracy score of DecisionTreeClassifier()
# 0.8584269662921349
# [[352  37]
#  [ 26  30]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       389
#            1       0.45      0.54      0.49        56
#
#     accuracy                           0.86       445
#    macro avg       0.69      0.72      0.70       445
# weighted avg       0.87      0.86      0.86       445
#
# Accuracy score of SVC(probability=True)
# 0.8741573033707866
# [[389   0]
#  [ 56   0]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       389
#            1       0.00      0.00      0.00        56
#
#     accuracy                           0.87       445
#    macro avg       0.44      0.50      0.47       445
# weighted avg       0.76      0.87      0.82       445
#
# Accuracy score of KNeighborsClassifier()
# 0.8786516853932584
# [[374  15]
#  [ 39  17]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       389
#            1       0.53      0.30      0.39        56
#
#     accuracy                           0.88       445
#    macro avg       0.72      0.63      0.66       445
# weighted avg       0.86      0.88      0.86       445

# %%
from sklearn.model_selection import cross_val_score

# %%
model=(lg,rfc,dt,sv,knn)
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Mean Accuracy of', m)
    print(score.mean())
    print('\n')
# Out:
# Mean Accuracy of LogisticRegression()
# 0.8691828191828191
#
#
# Mean Accuracy of RandomForestClassifier()
# 0.8772499772499772
#
#
# Mean Accuracy of DecisionTreeClassifier()
# 0.8293589043589045
#
#
# Mean Accuracy of SVC(probability=True)
# 0.8631176631176631
#
#
# Mean Accuracy of KNeighborsClassifier()
# 0.8368277368277368

# %%
Report={'Model':['LogisticR','RFC','DTC','SVC','KNN'],
        'Acc_test':[0.88,0.92,0.85,0.88,0.85],
        'Acc_cross':[0.86,0.87,0.81,0.86,0.83],
        'Difference':[0.88-0.86,0.92-0.87,0.85-0.81,0.88-0.86,0.85-0.83],}

# %%
Accuracy=pd.DataFrame(data=Report)
Accuracy
# Out:
#        Model  Acc_test  Acc_cross  Difference
# 0  LogisticR      0.88       0.86        0.02
# 1        RFC      0.92       0.87        0.05
# 2        DTC      0.85       0.81        0.04
# 3        SVC      0.88       0.86        0.02
# 4        KNN      0.85       0.83        0.02
