# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
pd.set_option('display.max_rows',None)
df.head(30)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# We notice there are values filled with '?' in the dataframe

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
# 33    875
# 28    867
# 30    861
# 37    858
# 25    841
# 27    835
# 32    828
# 38    827
# 39    815
# 29    813
# 41    808
# 24    798
# 40    794
# 26    785
# 42    780
# 43    770
# 22    765
# 20    753
# 46    737
# 45    734
# 44    724
# 21    720
# 19    712
# 47    708
# 50    602
# 51    595
# 49    577
# 18    550
# 48    543
# 52    478
# 53    464
# 55    419
# 54    415
# 17    395
# 58    366
# 56    366
# 57    358
# 59    355
# 60    312
# 61    300
# 62    258
# 63    230
# 64    208
# 65    178
# 67    151
# 66    150
# 68    120
# 69    108
# 70     89
# 71     72
# 72     67
# 73     64
# 74     51
# 76     46
# 75     45
# 90     43
# 77     29
# 78     23
# 80     22
# 79     22
# 81     20
# 82     12
# 84     10
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: Age, dtype: int64
#
#
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
# ...

# %% [markdown]
# From the above we see that there are values with '?' in the columns Workclass, Occupation, and Native Country.

# %% [markdown]
# Let us fill the '?' with the most frequently occuring values.

# %%
df['Workclass'] = df.Workclass.str.replace('?','Private')
df['Occupation'] = df.Occupation.str.replace('?','Prof-specialty')
df['Native_country'] = df.Native_country.str.replace('?','United-States')

# %%
df['Capital_gain'].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
# 5178        97
# 3103        97
# 4386        70
# 5013        69
# 8614        55
# 3325        53
# 2174        47
# 10520       43
# 4064        42
# 4650        41
# 14084       41
# 20051       37
# 3137        37
# 27828       34
# 594         34
# 3908        32
# 2829        31
# 13550       27
# 6849        27
# 14344       26
# 1055        25
# 2885        24
# 3411        24
# 4787        23
# 2176        23
# 3464        23
# 9386        22
# 2597        20
# 4101        20
# 2407        19
# 4865        17
# 2202        16
# 1506        15
# 3942        14
# 3674        14
# 4508        12
# 4416        12
# 3781        12
# 2580        12
# 10605       12
# 2907        11
# 25236       11
# 5455        11
# 6497        11
# 2354        11
# 2635        11
# 2463        11
# 2964         9
# 2105         9
# 6418         9
# 7430         9
# 2414         8
# 914          8
# ...

# %%
df['Capital_loss'].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
# 1485       51
# 2415       49
# 1602       47
# 1740       42
# 1590       40
# 1876       39
# 1672       34
# 1564       25
# 2258       25
# 1669       24
# 1741       24
# 2001       24
# 1980       23
# 1719       22
# 2002       21
# 2051       21
# 1408       21
# 1579       20
# 2377       20
# 1721       18
# 1504       18
# 1974       18
# 2339       17
# 2179       15
# 1628       15
# 1762       14
# 2444       12
# 2559       12
# 625        12
# 2824       10
# 2042        9
# 1617        9
# 2205        9
# 1651        9
# 2392        9
# 1594        8
# 1340        7
# 1380        7
# 1092        7
# 2174        7
# 1573        6
# 880         6
# 2246        6
# 2057        6
# 2206        6
# 2603        5
# 1668        4
# 1825        4
# 1258        4
# 2547        4
# 1726        4
# 213         4
# 2457        3
# 2129        3
# 653         3
# 2231        3
# 419         3
# ...

# %% [markdown]
# Majority of the values are 0 in the columns Capital_gain and Capital_loss so let us drop them.

# %%
df.drop(columns=['Capital_gain','Capital_loss'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# ...

# %%
#checking values in our target 
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
# There is a lot of imbalance in the data, we will us SMOTE() and oversample the data later.

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Hours_per_week
# count  32560.000000  3.256000e+04   32560.000000    32560.000000
# mean      38.581634  1.897818e+05      10.080590       40.437469
# std       13.640642  1.055498e+05       2.572709       12.347618
# min       17.000000  1.228500e+04       1.000000        1.000000
# 25%       28.000000  1.178315e+05       9.000000       40.000000
# 50%       37.000000  1.783630e+05      10.000000       40.000000
# 75%       48.000000  2.370545e+05      12.000000       45.000000
# max       90.000000  1.484705e+06      16.000000       99.000000

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Income'])
plt.show()

# %% [markdown]
# Most of the people have an income less than or equal to 50K.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Workclass'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can see the count of Private workclass is high compared to other workclass.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Education'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count of HS-grad(High School Graduate) is the highest compared to the other education qualifications.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Marital_status'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count of people who are married is the highest followed by nevermarried.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Occupation'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count of people who are in the position 'Prof-speciality' is the highest and the count of people in the position 'Armed-Forces' is the least.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Relationship'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count is high in the Husband Category and other relative has the least count.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Race'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Sex'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count of Male is high thar than the count of females.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Native_country'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The count of people who's native is The United States od America is the highest and all the other countires are almost negligible.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.catplot(x='Income',y='Age',data=df)
plt.title('Comparison between Income and Age')
plt.show()

# %% [markdown]
# We can see that most people below the age of 30 have a salary <=50k

# %%
plt.figure(figsize=(10,10))
sns.catplot(x='Income',y='Fnlwgt',data=df)
plt.title('Comparison between Income and Final Weight')
plt.show()

# %% [markdown]
# The relationship is not that significant

# %%
plt.figure(figsize=(10,10))
sns.catplot(x='Income',y='Hours_per_week',data=df,kind='bar',hue='Sex',palette='summer')
plt.title('Comparison between Income and Hours_per_week')
plt.show()

# %% [markdown]
# The income is >=50K when the working hours per week is high for both male and female.

# %%
plt.figure(figsize=(10,10))
sns.catplot(x='Income',y='Education_num',data=df,kind='bar',hue="Sex",palette='summer_r')
plt.title('Comparison between Income and Education_num')
plt.show()

# %% [markdown]
# The income is more than 50K for the people having high education_num.

# %%
plt.figure(figsize=(10,10))
sns.catplot(x='Workclass',y='Education_num', data=df,kind='bar',hue="Income",palette='Wistia_r');
plt.title('Comparision between Workclass and Education_num')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The people having gov sector jobs(State gov, Federal gov,Local gov) with high education number have the income >50K, the Private sector position with average education number have second highest income >=50K.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df["Workclass"],hue=df["Income"],palette='winter_r')
plt.title("Comparision between Workclass and Income")
plt.show()

# %% [markdown]
# The people who are working in the private sectors have the income <=50K and very few people in that sector have income >=50K.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df["Education"],hue=df["Income"],palette='ch:.25')
plt.title("Comparision between Education and Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The people who have completed their high school have income <=50K followed by the people who completed their Secondary School, the people who have done their Graduation are earning more i.e 50K.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Marital_status'],hue=df['Income'],palette='RdPu')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The people who are married have an income >=50K. The people who never married are majorly earning <=50K.

# %%
plt.figure(figsize=(10,10))
sns.countplot(df["Occupation"],hue=df["Income"],palette='Set1')
plt.title("Comparision between Occupation and Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Majority people who are in the Prof-speciality, Other-service, Adm-clerical, Sales and Craft repair have an income greater than 50K.
# Very few people who are in the position Handlers-clearners, Farming fishing have income less than 50K.

# %%
sns.catplot(x='Income',col='Sex',data=df,kind='count',palette="twilight")
plt.show()

# %% [markdown]
# Majority of males have an income greater than 50K.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df["Native_country"],hue=df["Income"],palette='spring')
plt.title("Comparision between Native_country and Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The people from United states are having high income when compared to the other countries.One reason for this could be because the data has maximum count of people whose native is the United States.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue='Income',palette='mako')

# %% [markdown]
# # Outliers

# %%
columns = ['Age','Fnlwgt','Education_num','Hours_per_week']
for i in columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# All the columns have outliers, let us remove then using Zscore method

# %%
from scipy.stats import zscore
col = df[["Age","Fnlwgt","Education_num","Hours_per_week"]]
z = np.abs(zscore(col))
z
# Out:
# array([[0.83709708, 1.0087417 , 1.13477863, 2.22212013],
#        [0.04264043, 0.24504633, 0.42002663, 0.03542999],
#        [1.05703146, 0.42576955, 1.19742926, 0.03542999],
#        ...,
#        [1.42358875, 0.3588108 , 0.42002663, 0.03542999],
#        [1.21562378, 0.11092744, 0.42002663, 1.65520046],
#        [0.98372   , 0.92986178, 0.42002663, 0.03542999]])

# %%
new_df = df[(z<3).all(axis=1)]
new_df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# ...

# %%
df.shape, new_df.shape
# Out:
# ((32560, 13), (31461, 13))

# %%
32560-31461
# Out:
# 1099

# %%
data_loss = (32560-31461)/32560*100
data_loss
# Out:
# 3.3753071253071254

# %% [markdown]
# We have los 3.37% data that is 1099 rows after removing the outliers.

# %% [markdown]
# # Skewness

# %%
new_df.skew()
# Out:
# Age               0.472279
# Fnlwgt            0.634828
# Education_num    -0.159752
# Hours_per_week   -0.341724
# dtype: float64

# %% [markdown]
# Only the feature Fnlwgt has skew, let us remove it using cube root method.

# %%
new_df['Fnlwgt'] = np.cbrt(new_df['Fnlwgt'])
new_df.skew()
# Out:
# Age               0.472279
# Fnlwgt           -0.376609
# Education_num    -0.159752
# Hours_per_week   -0.341724
# dtype: float64

# %%
sns.distplot(new_df['Fnlwgt'],hist=False)
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# The data now looks normalized

# %% [markdown]
# # Label Encoding

# %%
categorical_col = ['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
new_df[categorical_col] = new_df[categorical_col].apply(lbl.fit_transform)

# %%
new_df[categorical_col].head()
# Out:
#    Workclass  Education  Marital_status  Occupation  Relationship  Race  Sex  \
# 0          5          8               2           3             0     4    1
# 1          3         10               0           5             1     4    1
# 2          3          1               2           5             0     2    1
# 3          3          8               2           9             5     2    0
# 4          3         11               2           3             5     4    0
#
#    Native_country  Income
# 0              38       0
# 1              38       0
# 2              38       0
# 3               4       0
# 4              38       0

# %% [markdown]
# # Correlation

# %%
corr = new_df.corr()
corr
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.038024 -0.062328  -0.000447       0.053361
# Workclass       0.038024   1.000000 -0.021663   0.004652       0.003831
# Fnlwgt         -0.062328  -0.021663  1.000000  -0.024056      -0.031874
# Education      -0.000447   0.004652 -0.024056   1.000000       0.356040
# Education_num   0.053361   0.003831 -0.031874   0.356040       1.000000
# Marital_status -0.286424  -0.020597  0.026902  -0.039094      -0.065568
# Occupation     -0.001321   0.007551  0.001524  -0.041224       0.073927
# Relationship   -0.268028  -0.056825  0.009060  -0.015121      -0.102497
# Race            0.030679   0.046295 -0.006959   0.015552       0.030849
# Sex             0.091664   0.070095  0.023307  -0.024911       0.016662
# Hours_per_week  0.097510   0.030311 -0.015820   0.061325       0.160483
# Native_country -0.001039  -0.001602 -0.061390   0.068374       0.054510
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(new_df.corr(),annot=True,fmt='.2g',cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can observe the following from the heatmap:
# 1. There is not much correlation between the target and the features
# 2. The column Fnlwgt has the least correlation with the target, so let us drop it

# %%
plt.figure(figsize=(22,7))
new_df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar')
plt.xlabel('Feature',fontsize=18)
plt.ylabel('Target',fontsize=18)
plt.title('Correlation between label and features using bar plot',fontsize=25)
plt.show()

# %% [markdown]
# The features Workclass and Fnlwgt have the least correlation with thetarget so let us drop those columns.

# %%
new_df.drop(columns=['Workclass','Fnlwgt'],axis=1,inplace=True)

# %%
x = new_df.drop("Income",axis=1)
y = new_df["Income"]

# %%
x.shape, y.shape
# Out:
# ((31461, 10), (31461,))

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x.head()
# Out:
#         Age  Education  Education_num  Marital_status  Occupation  \
# 0  0.875057  -0.348344       1.154324       -0.403597   -0.784335
# 1 -0.025350   0.245782      -0.459657       -1.733114   -0.282327
# 2  1.100158  -2.427783      -1.266647       -0.403597   -0.282327
# 3 -0.775689  -0.348344       1.154324       -0.403597    0.721690
# 4 -0.100384   0.542845       1.557819       -0.403597   -0.784335
#
#    Relationship      Race       Sex  Hours_per_week  Native_country
# 0     -0.903178  0.391304  0.706601       -2.424121        0.254062
# 1     -0.281938  0.391304  0.706601       -0.008364        0.254062
# 2     -0.903178 -1.969806  0.706601       -0.008364        0.254062
# 3      2.203019 -1.969806 -1.415226       -0.008364       -5.457546
# 4      2.203019  0.391304 -1.415226       -0.008364        0.254062

# %%
y.value_counts()
# Out:
# 0    23853
# 1     7608
# Name: Income, dtype: int64

# %% [markdown]
# Let us oversample the data using SMOTE()

# %% [markdown]
# # Oversampling

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x, y = SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    23853
# 0    23853
# Name: Income, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import accuracy_score
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test = TTS(x,y,random_state=i,test_size=.30)
    DTC = DecisionTreeClassifier()
    DTC.fit(x_train,y_train)
    pred = DTC.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.8350335382895472 at random_state 96

# %%
x_train,x_test,y_train,y_test = TTS(x,y,random_state=maxRS,test_size=.30)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
predLR = lr.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7416852990497484
# [[5296 1981]
#  [1716 5319]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.74      7277
#            1       0.73      0.76      0.74      7035
#
#     accuracy                           0.74     14312
#    macro avg       0.74      0.74      0.74     14312
# weighted avg       0.74      0.74      0.74     14312

# %%
cm = confusion_matrix(y_test,predLR)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for LogisticRegression")
plt.show()

# %% [markdown]
# # DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
predDTC = dtc.predict(x_test)
print(accuracy_score(y_test,predDTC))
print(confusion_matrix(y_test,predDTC))
print(classification_report(y_test,predDTC))
# Out:
# 0.8334264952487423
# [[6045 1232]
#  [1152 5883]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      7277
#            1       0.83      0.84      0.83      7035
#
#     accuracy                           0.83     14312
#    macro avg       0.83      0.83      0.83     14312
# weighted avg       0.83      0.83      0.83     14312

# %%
cm = confusion_matrix(y_test,predDTC)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for Decision Tree Classifier")
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
predRFC = rfc.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8548071548351034
# [[6151 1126]
#  [ 952 6083]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      7277
#            1       0.84      0.86      0.85      7035
#
#     accuracy                           0.85     14312
#    macro avg       0.85      0.85      0.85     14312
# weighted avg       0.86      0.85      0.85     14312

# %%
cm = confusion_matrix(y_test,predRFC)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for RandomForestClassifier")
plt.show()

# %% [markdown]
# # KNN Classifier

# %%
knn = KNN()
knn.fit(x_train,y_train)
predknn = knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.8251117942984908
# [[5522 1755]
#  [ 748 6287]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82      7277
#            1       0.78      0.89      0.83      7035
#
#     accuracy                           0.83     14312
#    macro avg       0.83      0.83      0.82     14312
# weighted avg       0.83      0.83      0.82     14312

# %%
cm = confusion_matrix(y_test,predknn)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for KNeighborsClassifier")
plt.show()

# %% [markdown]
# # Gradient Boosting Classifier

# %%
gb = GradientBoostingClassifier()
gb.fit(x_train,y_train)
predGB = gb.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8378283957518167
# [[5697 1580]
#  [ 741 6294]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83      7277
#            1       0.80      0.89      0.84      7035
#
#     accuracy                           0.84     14312
#    macro avg       0.84      0.84      0.84     14312
# weighted avg       0.84      0.84      0.84     14312

# %%
cm = confusion_matrix(y_test,predGB)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for GradientBoostingClassifier")
plt.show()

# %% [markdown]
# # XG Boost Classifier

# %%
xgb = XGBClassifier()
xgb.fit(x_train,y_train)
predXGB = xgb.predict(x_test)
print(accuracy_score(y_test,predXGB))
print(confusion_matrix(y_test,predXGB))
print(classification_report(y_test,predXGB))
# Out:
# [13:47:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.8775852431525992
# [[6239 1038]
#  [ 714 6321]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      7277
#            1       0.86      0.90      0.88      7035
#
#     accuracy                           0.88     14312
#    macro avg       0.88      0.88      0.88     14312
# weighted avg       0.88      0.88      0.88     14312

# %%
cm = confusion_matrix(y_test,predXGB)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for XGBClassifier")
plt.show()

# %% [markdown]
# # Naive Bayes Classifier

# %%
nbc = GaussianNB()
nbc.fit(x_train,y_train)
predNBC = nbc.predict(x_test)
print(accuracy_score(y_test,predNBC))
print(confusion_matrix(y_test,predNBC))
print(classification_report(y_test,predNBC))
# Out:
# 0.7560089435438793
# [[5359 1918]
#  [1574 5461]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      7277
#            1       0.74      0.78      0.76      7035
#
#     accuracy                           0.76     14312
#    macro avg       0.76      0.76      0.76     14312
# weighted avg       0.76      0.76      0.76     14312

# %%
cm = confusion_matrix(y_test,predNBC)
x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]
sns.heatmap(cm,annot=True,fmt=".0f",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title("Confusion Matrix for NBClassifier")
plt.show()

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
print("Cross Validation Score using Linear Regression:",cross_val_score(lr,x,y,cv=5).mean())
# Out:
# Cross Validation Score using Linear Regression: 0.7471808076214929

# %%
print("Cross Validation Score using Decision Tree Classifier:",cross_val_score(dtc,x,y,cv=5).mean())
# Out:
# Cross Validation Score using Decision Tree Classifier: 0.830798795723499

# %%
print("Cross Validation Score using Random Forest Classifier:",cross_val_score(rfc,x,y,cv=5).mean())
# Out:
# Cross Validation Score using Random Forest Classifier: 0.8633939556957584

# %%
print("Cross Validation Score using KNN Classifier:",cross_val_score(knn,x,y,cv=5).mean())
# Out:
# Cross Validation Score using KNN Classifier: 0.8311327887579185

# %%
print("Cross Validation Score using Gradient Boosting Classifier:",cross_val_score(gb,x,y,cv=5).mean())
# Out:
# Cross Validation Score using Gradient Boosting Classifier: 0.8393081884180817

# %%
print("Cross Validation Score using XG Boosting Classifier:",cross_val_score(xgb,x,y,cv=5).mean())
# Out:
# [13:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:56:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:56:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print("Cross Validation Score using Naive Bayes Classifier:",cross_val_score(nbc,x,y,cv=5).mean())
# Out:
# Cross Validation Score using Naive Bayes Classifier: 0.760449465951434

# %% [markdown]
# ### Best Model - Random Forest Classifier

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'criterion':["gini","entropy"],
             'max_features':['auto','sqrt','log2'],
             'max_depth':[30,40,50],
             "min_samples_leaf":[2,3,4]}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [30, 40, 50],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [2, 3, 4]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 30,
#  'max_features': 'auto',
#  'min_samples_leaf': 2}

# %%
census = RandomForestClassifier(criterion='entropy',max_depth=30,max_features='auto',min_samples_leaf=2)
census.fit(x_train, y_train)
pred = census.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 86.14449413079933

# %% [markdown]
# The accuracy after hyperparameter Tuning is 86.14%

# %% [markdown]
# # Plotting ROC and compare AUC for all the models used

# %%
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve 

disp = plot_roc_curve(RFC,x_test,y_test)
plot_roc_curve(dtc, x_test, y_test, ax=disp.ax_) # ax_=Axes with confusion matrix
plot_roc_curve(lr, x_test, y_test, ax=disp.ax_)
plot_roc_curve(knn, x_test, y_test, ax=disp.ax_)
plot_roc_curve(gb, x_test, y_test, ax=disp.ax_)
plot_roc_curve(xgb, x_test, y_test, ax=disp.ax_)

plt.legend(prop={'size':11}, loc='lower right')
plt.show()

# %% [markdown]
# # ROC for Best model

# %%
plot_roc_curve(census, x_test, y_test)
plt.title("ROC for the best model")
plt.show()

# %% [markdown]
# # Saving the Model

# %%
import pickle
filename = 'census_income.pkl'
pickle.dump(rfc, open(filename, 'wb'))

# %% [markdown]
# # Prediction

# %%
predict_df = pd.DataFrame([rfc.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
predict_df
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      1      0      0      0      1      1      0      0      0
# Original       1      1      0      0      1      1      0      0      0
#
#            9      ...  14302  14303  14304  14305  14306  14307  14308  14309  \
# Predicted      0  ...      1      0      0      1      0      0      0      0
# Original       0  ...      0      0      0      1      1      0      0      0
#
#            14310  14311
# Predicted      0      0
# Original       0      0
#
# [2 rows x 14312 columns]
